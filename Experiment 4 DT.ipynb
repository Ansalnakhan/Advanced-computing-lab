# %% [markdown]
# <a href="https://colab.research.google.com/github/Ansalnakhan/Advanced-computing-lab/blob/main/Experiment%204%20DT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
file=pd.read_csv("/content/bank.csv")

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()

# %%
z=["job", "marital", "education", "default", "housing",	"loan",	"contact", "month"]

# %%
file[z]=file[z].apply(le.fit_transform)

# %%
file
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       59    0        1          1        0     2343        1     0        2
# 1       56    0        1          1        0       45        0     0        2
# 2       41    9        1          1        0     1270        1     0        2
# 3       55    7        1          1        0     2476        1     0        2
# 4       54    0        1          2        0      184        0     0        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 11157   33    1        2          0        0        1        1     0        0
# 11158   39    7        1          1        0      733        0     0        2
# 11159   32    9        2          1        0       29        0     0        0
# 11160   43    9        1          1        0        0        0     1        0
# 11161   34    9        1          1        0        0        0     0        0
#
# ...

# %%
X=file[["job", "marital", "education", "default", "housing",	"loan",	"contact", "month"]]
Y=file["deposit"]
X
# Out:
#        job  marital  education  default  housing  loan  contact  month
# 0        0        1          1        0        1     0        2      8
# 1        0        1          1        0        0     0        2      8
# 2        9        1          1        0        1     0        2      8
# 3        7        1          1        0        1     0        2      8
# 4        0        1          2        0        0     0        2      8
# ...    ...      ...        ...      ...      ...   ...      ...    ...
# 11157    1        2          0        0        1     0        0      0
# 11158    7        1          1        0        0     0        2      6
# 11159    9        2          1        0        0     0        0      1
# 11160    9        1          1        0        0     1        0      8
# 11161    9        1          1        0        0     0        0      5
#
# [11162 rows x 8 columns]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(random_state=0,max_depth=1)

# %%
clf = DecisionTreeClassifier(random_state=0)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,train_size=0.7)

# %%
clf=clf.fit(xtrain,ytrain)

# %%
res=clf.predict(xtrain)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(ytrain, res)
accuracy_score
# Out:
# <function sklearn.metrics._classification.accuracy_score>

# %%
from sklearn import tree

# %%
import graphviz

# %%
dot_data = tree.export_graphviz(clf)

# %%
graph = graphviz.Source(dot_data)

# %%
graph
